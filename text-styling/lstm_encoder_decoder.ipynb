# %%
'''Example script to generate text from Nietzsche's writings.

At least 20 epochs are required before the generated text
starts sounding coherent.

It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.

If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, GRU, Input, Flatten, Masking, merge
from keras.optimizers import RMSprop, SGD, Adam
from keras.utils.data_utils import get_file
from keras.models import Model
import numpy as np
import random
import sys
import re

#import nltk.data

caps = "([A-Z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"

def split_into_sentences(text):
    text = " " + text + "  "
    text = text.replace("\n"," ")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + caps + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(caps + "[.]" + caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + caps + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    #if "\'" in text: text = text.replace("\'", " ")
    text = text.replace(". ","._<stop> ")
    text = text.replace("? ","?_<stop> ")
    text = text.replace("! ","!_<stop> ")
    text = text.replace("<prd> ",".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    out = []
    for s in sentences:
        if (len(s) > 30) and (len(s) < 500):
            out.append(s)
    return out

path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower().replace('\n', ' ').replace('=', ' ').replace(r"\\'", " ")
print('corpus length:', len(text))

# nltk.download()
#tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
#tokenized = tokenizer.tokenize(text)

def text_generator():
    sentences = np.array(split_into_sentences(text))
    sentences = sorted(sentences, key=len)
    chars = sorted(list(set("".join(sentences))))

    EXAMPLES_PER_SENTENCE = 1
    SENTENCE_BATCH_SIZE = 64
    batches = []
    for i in range(0, len(sentences), SENTENCE_BATCH_SIZE): # len(sentences)
        print('Preparing batch: ', i)
        sentence_batch = sentences[i:i + SENTENCE_BATCH_SIZE]
        maxlen_batch = len(max(sentence_batch, key=len))

        X = np.zeros((EXAMPLES_PER_SENTENCE*SENTENCE_BATCH_SIZE, maxlen_batch, len(chars)), dtype=np.int32)
        x = np.zeros((EXAMPLES_PER_SENTENCE*SENTENCE_BATCH_SIZE, maxlen_batch, len(chars)), dtype=np.int32)
        y = np.zeros((EXAMPLES_PER_SENTENCE*SENTENCE_BATCH_SIZE, len(chars)), dtype=np.int32)

        for i, sentence in enumerate(sentence_batch):

            for t, char in enumerate(sentence):
                X[EXAMPLES_PER_SENTENCE*i:EXAMPLES_PER_SENTENCE*(i+1), t, char_indices[char]] = 1

            example_positions = np.random.random_integers(0, len(sentence)-2, EXAMPLES_PER_SENTENCE)
            for t in range(EXAMPLES_PER_SENTENCE):
                taget_pos = example_positions[t]+1
                x[EXAMPLES_PER_SENTENCE*i+t, 0:taget_pos, :] = X[EXAMPLES_PER_SENTENCE*i, 0:taget_pos, :]
                y[EXAMPLES_PER_SENTENCE*i+t, char_indices[sentence[taget_pos]]] = 1
            # This is to learn predicting the first symbol in the sequence
            x[EXAMPLES_PER_SENTENCE * i, 1:, :] = 0
            y[EXAMPLES_PER_SENTENCE * i, char_indices[sentence[1]]] = 1

        batches.append(([X, x], y))

    cum_count=0
    while 1:
        count=0
        cum_count += 1
        for batch in batches:
            print('batch number: ', count, ', cumulative batch number: ', cum_count)
            count += 1
            yield batch

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

#print('Vectorization...')
#X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
#y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
#for i, sentence in enumerate(sentences):
#    for t, char in enumerate(sentence):
#        X[i, t, char_indices[char]] = 1
#    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
#model = Sequential()
#model.add(LSTM(128, input_shape=(maxlen, len(chars)))) # return_sequences
#model.add(Dense(len(chars)))
#model.add(Activation('softmax'))

LSTM_WIDTH = 256
context_input = Input(shape=(None, len(chars)))
x = Masking(mask_value=0)(context_input)
x = LSTM(LSTM_WIDTH, return_sequences=True, dropout_W=0.2)(x)
x = LSTM(LSTM_WIDTH, return_sequences=True, dropout_W=0.2)(x)
encoder_output = LSTM(LSTM_WIDTH, return_sequences=False, dropout_W=0.2)(x)

teacher_input = Input(shape=(None, len(chars)))
decoder_input = Masking(mask_value=0)(teacher_input)
#decoder_input = merge([teacher_input, encoder_output], mode='concat', concat_axis=1)
y = GRU(LSTM_WIDTH, return_sequences=True, go_backwards=True, dropout_W=0.2, )(decoder_input)
y = GRU(LSTM_WIDTH, return_sequences=True, dropout_W=0.2)(y)
y = GRU(LSTM_WIDTH, return_sequences=False, dropout_W=0.2)(y)
decoder_output = Dense(len(chars), activation='softmax')(y)

model = Model(input=[context_input, teacher_input], output=[decoder_output])

optimizer = Adam(clipnorm=5.0)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration

baseline_gen = text_generator()

for iteration in range(1, 100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    #model.fit(X, y,
    #          batch_size=512,
    #          nb_epoch=1)

    model.fit_generator(baseline_gen, steps_per_epoch=2700/64, nb_epoch=1, verbose=1, nb_worker=1)



#    test_sentence = 'eventually--the memory yields._'
#    tes_frag = 'eventually--the m'
#    prediction = model.predict_on_batch(test_set[0])


    # 'eventually--the memory yields._', 'whom i thank when in my bliss?_', 'or even wagner\'s "tannhauser"!_', 'the eternal, fatal "too late"!_', '_must_ we not be dupers also"?_', '17   metaphysical explanation._', 'this is the age of comparison!_', 'history of the moral feelings._', '43   inhuman men as survivals._', '65   whither honesty may lead._'


#    start_index = random.randint(0, len(text) - maxlen - 1)

#    if (iteration % 10 == 0):
#        for diversity in [0.2, 0.5, 1.0, 1.2]:
#            print()
#            print('----- diversity:', diversity)#

#            generated = ''
#            sentence = text[start_index: start_index + maxlen]
#            generated += sentence
#            print('----- Generating with seed: "' + sentence + '"')
#            #sys.stdout.write(generated)
#
#            for i in range(400):
#                x = np.zeros((1, maxlen, len(chars)))
#                for t, char in enumerate(sentence):
#                    x[0, t, char_indices[char]] = 1.
#
#                preds = model.predict(x, verbose=0)[0]
#                next_index = sample(preds, diversity)
#                next_char = indices_char[next_index]
#
#                generated += next_char
#                sentence = sentence[1:] + next_char#
#
#            #    sys.stdout.write(next_char)
#            #    sys.stdout.flush()
#            print(generated)


# Some simple test of model prediction performance
test_set = baseline_gen.__next__()
prediction = model.predict_on_batch(test_set[0])
for i in range(len(test_set[1])):

    sentence = np.argmax(test_set[0][0][i], axis=1)
    sentence_decode = ''
    for t in range(len(sentence)):
        sentence_decode += indices_char[sentence[t]]

    frag = np.argmax(test_set[0][1][i], axis=1)
    frag_decode = ''
    for t in range(len(frag)):
        frag_decode += indices_char[frag[t]]

    predicted_symbol = indices_char[np.argmax(prediction[i])]
    print('Sentence: ', sentence_decode)
    print('Frag: ', frag_decode, ' Predicted symbol: \"%s\"' %(predicted_symbol) )
# Out:
# corpus length: 600893
# total chars: 55
# nb sequences: 200285
# Build model...
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:149: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(256, return_sequences=True, dropout=0.2)`
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:150: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(256, return_sequences=True, dropout=0.2)`
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:151: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(256, return_sequences=False, dropout=0.2)`
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:156: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(256, return_sequences=True, go_backwards=True, dropout=0.2)`
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:157: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(256, return_sequences=True, dropout=0.2)`
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:158: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(256, return_sequences=False, dropout=0.2)`
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:161: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:188: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., steps_per_epoch=42.1875, verbose=1, epochs=1, workers=1)`
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# Preparing batch:  0
# Preparing batch:  64
# Preparing batch:  128
# Preparing batch:  192
# Preparing batch:  256
# Preparing batch:  320
# Preparing batch:  384
# Preparing batch:  448
# Preparing batch:  512
# Preparing batch:  576
# Preparing batch:  640
# Preparing batch:  704
# Preparing batch:  768
# Preparing batch:  832
# Preparing batch:  896
# Preparing batch:  960
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 29 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 30 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 31 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 32 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 33 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 34 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 35 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 36 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 37 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 38 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 39 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 40 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 41 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 42 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 43 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 44 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 45 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 46 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 47 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 48 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 49 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 50 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 51 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 52 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 53 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 54 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 55 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 56 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 57 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 58 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 59 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 60 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 61 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 62 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 63 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 64 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 65 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 66 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 67 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 68 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 69 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 70 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 71 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 72 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 73 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 74 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 75 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 76 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 77 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 78 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 79 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 80 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 81 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 82 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 83 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 84 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 85 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 86 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 87 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 88 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 89 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 90 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 91 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 92 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 93 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 94 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 95 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 96 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 97 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 98 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 99 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 100 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 101 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 102 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 103 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 104 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 105 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 106 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 107 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 108 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 109 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 110 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 111 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 112 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 113 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 114 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 115 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 116 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 117 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 118 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 119 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 120 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 121 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 122 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 123 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 124 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 125 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 126 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 127 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 128 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 129 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 130 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 131 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 132 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 133 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 134 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 135 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 136 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 137 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 138 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 139 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 140 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 141 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 142 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 143 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 144 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 145 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 146 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 147 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 148 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 149 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 150 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0, 151 + 1) instead
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:95: DeprecationWarning: This function is deprecated. Please call randint(0,
# 37/42 [=========================>....] - ETA: 9s - loss: 5.7163 batch number:  0 , cumulative batch number:  30
# 38/42 [==========================>...] - ETA: 7s - loss: 5.7151batch number:  1 , cumulative batch number:  30
# 39/42 [==========================>...] - ETA: 5s - loss: 5.7134batch number:  2 , cumulative batch number:  30
# 40/42 [===========================>..] - ETA: 3s - loss: 5.7129batch number:  3 , cumulative batch number:  30
# 41/42 [============================>.] - ETA: 2s - loss: 5.7065batch number:  4 , cumulative batch number:  30
# 42/42 [============================>.] - ETA: 0s - loss: 5.7109batch number:  5 , cumulative batch number:  30
# 43/42 [==============================] - 82s - loss: 5.7121
#
# --------------------------------------------------
# Iteration 23
# batch number: Epoch 1/1
#  6 , cumulative batch number:  30
# batch number:  7 , cumulative batch number:  30
# batch number:  8 , cumulative batch number:  30
# batch number:  9 , cumulative batch number:  30
# batch number:  10 , cumulative batch number:  30
# batch number:  11 , cumulative batch number:  30
# batch number:  12 , cumulative batch number:  30
# batch number:  13 , cumulative batch number:  30
# batch number:  14 , cumulative batch number:  30
# batch number:  15 , cumulative batch number:  30
# batch number:  16 , cumulative batch number:  30
#  1/42 [..............................] - ETA: 25s - loss: 5.5917batch number:  17 , cumulative batch number:  30
#  2/42 [>.............................] - ETA: 26s - loss: 5.7331batch number:  18 , cumulative batch number:  30
#  3/42 [=>............................] - ETA: 26s - loss: 5.6158batch number:  19 , cumulative batch number:  30
#  4/42 [=>............................] - ETA: 27s - loss: 5.6195batch number:  20 , cumulative batch number:  30
#  5/42 [==>...........................] - ETA: 28s - loss: 5.7013batch number:  21 , cumulative batch number:  30
#  6/42 [===>..........................] - ETA: 28s - loss: 5.6877batch number:  22 , cumulative batch number:  30
#  7/42 [===>..........................] - ETA: 28s - loss: 5.7073batch number:  23 , cumulative batch number:  30
#  8/42 [====>.........................] - ETA: 28s - loss: 5.7193batch number:  24 , cumulative batch number:  30
#  9/42 [=====>........................] - ETA: 28s - loss: 5.6714batch number:  25 , cumulative batch number:  30
# 10/42 [======>.......................] - ETA: 28s - loss: 5.6469batch number:  26 , cumulative batch number:  30
# 11/42 [======>.......................] - ETA: 28s - loss: 5.6726batch number:  27 , cumulative batch number:  30
# 12/42 [=======>......................] - ETA: 28s - loss: 5.6612batch number:  28 , cumulative batch number:  30
# 13/42 [========>.....................] - ETA: 28s - loss: 5.6580batch number:  29 , cumulative batch number:  30
# 14/42 [========>.....................] - ETA: 28s - loss: 5.6396batch number:  30 , cumulative batch number:  30
# 15/42 [=========>....................] - ETA: 28s - loss: 5.6316batch number:  31 , cumulative batch number:  30
# 16/42 [==========>...................] - ETA: 28s - loss: 5.6504batch number:  32 , cumulative batch number:  30
# 17/42 [===========>..................] - ETA: 28s - loss: 5.6431batch number:  33 , cumulative batch number:  30
# 18/42 [===========>..................] - ETA: 27s - loss: 5.6401batch number:  34 , cumulative batch number:  30
# 19/42 [============>.................] - ETA: 27s - loss: 5.6527batch number:  35 , cumulative batch number:  30
# 20/42 [=============>................] - ETA: 27s - loss: 5.6598batch number:  36 , cumulative batch number:  30
# 21/42 [=============>................] - ETA: 26s - loss: 5.6600batch number:  37 , cumulative batch number:  30
# 22/42 [==============>...............] - ETA: 26s - loss: 5.6531batch number:  38 , cumulative batch number:  30
# 23/42 [===============>..............] - ETA: 26s - loss: 5.6599batch number:  39 , cumulative batch number:  30
# 24/42 [================>.............] - ETA: 25s - loss: 5.6603batch number:  0 , cumulative batch number:  31
# 25/42 [================>.............] - ETA: 24s - loss: 5.6599batch number:  1 , cumulative batch number:  31
# 26/42 [=================>............] - ETA: 24s - loss: 5.6585batch number:  2 , cumulative batch number:  31
# 27/42 [==================>...........] - ETA: 23s - loss: 5.6588batch number:  3 , cumulative batch number:  31
# 28/42 [==================>...........] - ETA: 22s - loss: 5.6511batch number:  4 , cumulative batch number:  31
# 29/42 [===================>..........] - ETA: 21s - loss: 5.6589batch number:  5 , cumulative batch number:  31
# 30/42 [====================>.........] - ETA: 20s - loss: 5.6623batch number:  6 , cumulative batch number:  31
# 31/42 [=====================>........] - ETA: 19s - loss: 5.6619batch number:  7 , cumulative batch number:  31
# 32/42 [=====================>........] - ETA: 18s - loss: 5.6503batch number:  8 , cumulative batch number:  31
# 33/42 [======================>.......] - ETA: 17s - loss: 5.6538batch number:  9 , cumulative batch number:  31
# 34/42 [=======================>......] - ETA: 16s - loss: 5.5704batch number:  10 , cumulative batch number:  31
# 35/42 [=======================>......] - ETA: 13s - loss: 5.6160batch number:  11 , cumulative batch number:  31
# 36/42 [========================>.....] - ETA: 11s - loss: 5.6482batch number:  12 , cumulative batch number:  31
# 37/42 [=========================>....] - ETA: 9s - loss: 5.6788 batch number:  13 , cumulative batch number:  31
# 38/42 [==========================>...] - ETA: 7s - loss: 5.6981batch number:  14 , cumulative batch number:  31
# 39/42 [==========================>...] - ETA: 5s - loss: 5.7030batch number:  15 , cumulative batch number:  31
# 40/42 [===========================>..] - ETA: 3s - loss: 5.7058batch number:  16 , cumulative batch number:  31
# 41/42 [============================>.] - ETA: 2s - loss: 5.7036batch number:  17 , cumulative batch number:  31
# 42/42 [============================>.] - ETA: 0s - loss: 5.7073batch number:  18 , cumulative batch number:  31
# 43/42 [==============================] - 72s - loss: 5.7007
#
# --------------------------------------------------
# Iteration 24
# batch number:  Epoch 1/119
#  , cumulative batch number:  31
# batch number:  20 , cumulative batch number:  31
# batch number:  21 , cumulative batch number:  31
# batch number:  22 , cumulative batch number:  31
# batch number:  23 , cumulative batch number:  31
# batch number:  24 , cumulative batch number:  31
# batch number:  25 , cumulative batch number:  31
# batch number:  26 , cumulative batch number:  31
# batch number:  27 , cumulative batch number:  31
# batch number:  28 , cumulative batch number:  31
# batch number:  29 , cumulative batch number:  31
#  1/42 [..............................] - ETA: 60s - loss: 5.4741batch number:  30 , cumulative batch number:  31

# %%
# !pip install git+https://github.com/fchollet/keras.git
# Out:
# Collecting git+https://github.com/fchollet/keras.git
#   Cloning https://github.com/fchollet/keras.git to /tmp/pip-eyppzp7z-build
# Requirement already satisfied: theano in /opt/conda/lib/python3.6/site-packages (from Keras==2.0.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from Keras==2.0.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from Keras==2.0.3)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from theano->Keras==2.0.3)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from theano->Keras==2.0.3)
# Installing collected packages: Keras
#   Found existing installation: Keras 2.0.2
#     Uninstalling Keras-2.0.2:
#       Successfully uninstalled Keras-2.0.2
# done
# Successfully installed Keras-2.0.3
